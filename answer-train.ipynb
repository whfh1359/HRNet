# %%
import pandas as pd
from matplotlib import rcParams
import matplotlib.pyplot as plt
import seaborn as sns
# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %%
df = pd.read_csv('answer_train_distance.csv')
df.head()
# Out:
#    filename  right_medial_x  right_medial_y  Y/N  right_f_x  right_f_y  Y/N.1  \
# 0         1            1763            1693    2        786       2308      2
# 1         2             904             808    2        391       1195      2
# 2         3             945             368    2        409        851      2
# 3         4             935             821    2        408       1231      2
# 4         5             937             902    2        414       1372      2
#
#    left_medial_x  left_medial_y  Y/N.2  left_f_x  left_f_y  Y/N.3  letter_R_x  \
# 0           2175           1675      2      3089      2308      2           0
# 1           1653            838      2      2189      1219      2         200
# 2           1632            419      2      2177       863      2          26
# 3           1680            853      2      2197      1259      2          13
# 4           1667            923      2      2206      1378      2          89
#
# ...

# %%
df[df['letter_R_x']>600]
# Out:
#       filename  right_medial_x  right_medial_y  Y/N  right_f_x  right_f_y  \
# 6            7            1388            1630    2        436       2219
# 33          34            1067             828    2         72       1159
# 185        186            1129            1025    2        669       1361
# 477        478            1386            1405    2        334       2368
# 1194      1195             591             590    2        138        924
# 1312      1313            1336             957    2        584       1440
#
#       Y/N.1  left_medial_x  left_medial_y  Y/N.2  left_f_x  left_f_y  Y/N.3  \
# 6         2           2843           1648      2      3840      2233      2
# 33        2           1577            857      2      2145      1279      2
# 185       2           1565           1061      2      2057      1389      2
# 477       2           3641           2142      2         0         0      0
# ...

# %%
df[df['letter_R_x']>400]
# Out:
#       filename  right_medial_x  right_medial_y  Y/N  right_f_x  right_f_y  \
# 6            7            1388            1630    2        436       2219
# 33          34            1067             828    2         72       1159
# 185        186            1129            1025    2        669       1361
# 477        478            1386            1405    2        334       2368
# 1194      1195             591             590    2        138        924
# 1212      1213            1131            1354    2        645       1780
# 1238      1239            1533            2371    2        655       3042
# 1312      1313            1336             957    2        584       1440
# 1416      1417            1219             723    2        762       1095
# 1428      1429            1121             997    2        583       1409
# 1658      1659             951            1149    2        420       1577
# 1767      1768            1340            1602    2        737       2055
#
# ...

# %%
df[(df['letter_L_x']<1000) & (df['letter_L_x']> 0)]
# Out:
#       filename  right_medial_x  right_medial_y  Y/N  right_f_x  right_f_y  \
# 1300      1301             889             901    2        494       1135
#
#       Y/N.1  left_medial_x  left_medial_y  Y/N.2  left_f_x  left_f_y  Y/N.3  \
# 1300      2           1369            897      2      1787      1115      2
#
#       letter_R_x  letter_R_y  Y/N.4  letter_L_x  letter_L_y  Y/N.5
# 1300           0           0      0         219         640      2

# %%
plt.scatter(df.letter_R_x,df.letter_R_y,alpha=0.2,s=100,c=df.letter_R_y,cmap='viridis')
plt.title('train Scatter Plot with letter_R_x & Color(letter_R_y)', fontsize=14)
plt.xlabel('letter_R_x', fontsize=12)
plt.ylabel('letter_R_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
plt.scatter(df2.letter_R_x,df2.letter_R_y,alpha=0.2,s=100,c=df2.letter_R_y,cmap='viridis')
plt.title('test Scatter Plot with letter_R_x & Color(letter_R_y)', fontsize=14)
plt.xlabel('letter_R_x', fontsize=12)
plt.ylabel('letter_R_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
plt.scatter(df.letter_L_x,df.letter_L_y,alpha=0.2,s=100,c=df.letter_L_y,cmap='viridis')
plt.title('train Scatter Plot with left_f_x & Color(left_f_y)', fontsize=14)
plt.xlabel('letter_L_x', fontsize=12)
plt.ylabel('letter_L_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
plt.scatter(df2.letter_L_x,df2.letter_L_y,alpha=0.2,s=100,c=df2.letter_L_y,cmap='viridis')
plt.title('test Scatter Plot with letter_L_x & Color(letter_L_y)', fontsize=14)
plt.xlabel('letter_L_x', fontsize=12)
plt.ylabel('letter_L_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
df2 = pd.read_csv('predict_addL.csv')
df2 = df2.drop(['Unnamed: 0'], axis = 1)
df2[df2['file_name'] ==2028]
# Out:
#     file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 85       2028             593             852        135       1173
#
#     left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 85           1166            852      1601      1127          20         806
#
#     letter_L_x  letter_L_y  right_medial_prob  right_f_prob  left_medial_prob  \
# 85        1716         737           0.929329      0.996426          0.992047
#
#     left_f_prob  letter_R_prob  letter_L_prob
# 85     0.921754       0.989072       0.414018

# %%
plt.scatter(df2.letter_R_x,df2.letter_R_y,alpha=0.2,s=100,c=df2.letter_R_y,cmap='viridis')
plt.title('test Scatter Plot with letter_R_x & Color(letter_R_y)', fontsize=14)
plt.xlabel('letter_R_x', fontsize=12)
plt.ylabel('letter_R_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
plt.scatter(df2.letter_L_x,df2.letter_L_y,alpha=0.2,s=100,c=df2.letter_L_y,cmap='viridis')
plt.title('test Scatter Plot with letter_L_x & Color(letter_L_y)', fontsize=14)
plt.xlabel('letter_L_x', fontsize=12)
plt.ylabel('letter_L_y', fontsize=12)
plt.colorbar()
plt.show()

# %%
df2[df2['file_name'] ==2160]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 217       2160             805            1033        387       1395
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 217           1251            977      1696      1339          80        1451
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 217        2087        1256           0.965408      0.970151
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 217          0.998159     0.979628       0.993579       0.580318

# %%
df2[df2['file_name'] ==2416]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 473       2416             805             893        387       1200
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 473           1111            866      1585      1200          80         169
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 473        1919         921           0.952484      0.964974
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 473          0.992677     0.998496       0.915909       0.975074

# %%
df2[df2['file_name'] ==2426]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 483       2426            1090            1380        582       1771
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 483           1637           1380      2184      1810        -375        -866
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 483        2770        1106           0.962647      0.984101
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 483          0.992542     0.977271       0.125222       0.894624

# %%
df2[df2['file_name'] ==2485]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 542       2485            1344            1751        331       2314
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 542           2806           1808      3706      2426          50        3495
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 542        4213        1189           0.979252      0.976967
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 542          0.926819     0.991497       0.872306       0.999425

# %%
df2[df2['file_name'] ==2598]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 655       2598            1101            1104        585       1472
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 655           1911           1067      2426      1472          -3        2283
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 655        2647         405           0.946109      0.980159
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 655          0.999353     0.986809       0.878419       0.379494
