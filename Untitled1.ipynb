# %%
import csv
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
result_score = pd.read_csv('result_score_addL.csv')
result_score
# Out:
#     Threshold  R_accuracy_score  R_recall_score  R_precision_score  \
# 0        0.35           0.96871         0.99804            0.95318
# 1        0.40           0.97112         0.99804            0.95677
# 2        0.45           0.97112         0.99804            0.95677
# 3        0.50           0.97353         0.99804            0.96038
# 4        0.55           0.97473         0.99804            0.96219
# 5        0.60           0.97353         0.99608            0.96212
# 6        0.65           0.97353         0.99608            0.96212
# 7        0.70           0.97353         0.99608            0.96212
# 8        0.75           0.97112         0.99216            0.96198
# 9        0.80           0.96992         0.99020            0.96190
# 10       0.85           0.96871         0.98431            0.96538
# 11       0.90           0.96510         0.96863            0.97436
#
#     R_f1_score  L_accuracy_score  L_recall_score  L_precision_score  \
# ...

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 20,8.27

# %%
fig, ax = plt.subplots(ncols=2)

sns.pointplot(data = result_score, x = "Threshold", y = "R_f1_score", ax=ax[0])
sns.pointplot(data = result_score, x = "Threshold", y = "L_f1_score", ax=ax[1])
#sns.pointplot(data = sens, x = "Threshold", y = "Accuracy", ax=ax[2])
# Out:
# <AxesSubplot:xlabel='Threshold', ylabel='L_f1_score'>

# %%
fig, ax = plt.subplots(ncols=2)

sns.pointplot(data = result_score, x = "Threshold", y = "R_accuracy_score", ax=ax[0])
sns.pointplot(data = result_score, x = "Threshold", y = "L_accuracy_score", ax=ax[1])
#sns.pointplot(data = sens, x = "Threshold", y = "Accuracy", ax=ax[2])
# Out:
# <AxesSubplot:xlabel='Threshold', ylabel='L_accuracy_score'>

# %%
result_score[result_score['Threshold'] == 0.55]
# Out:
#    Threshold  R_accuracy_score  R_recall_score  R_precision_score  R_f1_score  \
# 4       0.55           0.97473         0.99804            0.96219     0.97979
#
#    L_accuracy_score  L_recall_score  L_precision_score  L_f1_score
# 4           0.96751         0.99083            0.94945      0.9697

# %%
result_score[result_score['Threshold'] == 0.80]
# Out:
#    Threshold  R_accuracy_score  R_recall_score  R_precision_score  R_f1_score  \
# 9        0.8           0.96992          0.9902             0.9619     0.97585
#
#    L_accuracy_score  L_recall_score  L_precision_score  L_f1_score
# 9           0.98315         0.98853            0.97955     0.98402

# %%
result_score_best = pd.read_csv('result_score_addL_best.csv')
result_score_best
# Out:
#    R_accuracy_score  R_recall_score  R_precision_score  R_f1_score  \
# 0           0.97473         0.99804            0.96219     0.97979
#
#    L_accuracy_score  L_recall_score  L_precision_score  L_f1_score
# 0           0.98315         0.98853            0.97955     0.98402

# %%
predict_addL = pd.read_csv('predict_addL.csv')
predict_addL = predict_addL.drop(['Unnamed: 0'], axis = 1)
predict_addL[predict_addL['file_name']==2212]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 269       2212             693             949        303       1311
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 269           1195            949      1557      1311        1195         949
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 269        -267         434           0.362048      0.557694
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 269          0.499464      0.59243       0.186382       0.071286

# %%
predict_addL[predict_addL['file_name']==2401]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 458       2401             833            1005        387       1311
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 458           1083            977      1501      1311        1446        1339
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 458        2351         434           0.956719      0.982999
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 458          0.943678     0.988286       0.064504       0.188841
