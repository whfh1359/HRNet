# %%
#import cv2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('c_kneebone_fix_total_add_prob_2.csv')
df
# Out:
#                               file_name  right_medial_x  right_medial_y  \
# 1477 776  845  191 1267 1620        845            2204            1267
# 1912 760  752  392 1094 1339        752            1681            1068
# 1408 1456 1470 500 2033 2806       1526            3763            2145
# 1970 681  997  313 1286 1260        997            1602            1286
# 1647 833  866  443 1144 1306        866            1669            1144
# ...                                 ...             ...             ...
# 1738 693  866  247 1172 1195        838            1613            1144
# 1796 786  944  418 1181 1155        944            1523            1207
# 1628 1129 1402 582 1832 1715       1402            2301            1793
# 1999 749  921  359 1256 1278        893            1724            1228
# 1697 1068 715  646 1105 1425        747            1880            1105
#
#                               right_f_x  right_f_y  left_medial_x  \
# ...

# %%
df = df.reset_index()
df
# Out:
#      level_0  level_1  level_2  level_3  level_4  level_5  file_name  \
# 0       1477      776      845      191     1267     1620        845
# 1       1912      760      752      392     1094     1339        752
# 2       1408     1456     1470      500     2033     2806       1526
# 3       1970      681      997      313     1286     1260        997
# 4       1647      833      866      443     1144     1306        866
# ..       ...      ...      ...      ...      ...      ...        ...
# 595     1738      693      866      247     1172     1195        838
# 596     1796      786      944      418     1181     1155        944
# 597     1628     1129     1402      582     1832     1715       1402
# 598     1999      749      921      359     1256     1278        893
# 599     1697     1068      715      646     1105     1425        747
#
#      right_medial_x  right_medial_y  right_f_x  right_f_y  left_medial_x  \
# ...

# %%
df['right_medial_prob'] = 0
df['right_f_prob'] = 0
df['left_medial_prob'] = 0
df['left_f_prob'] = 0
df['letter_R_prob'] = 0
df['letter_L_prob'] = 0

# %%
df = df.shift(periods=6, axis="columns")
df
# Out:
#      level_0  level_1  level_2  level_3  level_4  level_5  file_name  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN       1477
# 1        NaN      NaN      NaN      NaN      NaN      NaN       1912
# 2        NaN      NaN      NaN      NaN      NaN      NaN       1408
# 3        NaN      NaN      NaN      NaN      NaN      NaN       1970
# 4        NaN      NaN      NaN      NaN      NaN      NaN       1647
# ..       ...      ...      ...      ...      ...      ...        ...
# 595      NaN      NaN      NaN      NaN      NaN      NaN       1738
# 596      NaN      NaN      NaN      NaN      NaN      NaN       1796
# 597      NaN      NaN      NaN      NaN      NaN      NaN       1628
# 598      NaN      NaN      NaN      NaN      NaN      NaN       1999
# 599      NaN      NaN      NaN      NaN      NaN      NaN       1697
#
#      right_medial_x  right_medial_y  right_f_x  ...  letter_R_x  letter_R_y  \
# ...

# %%
df = df.drop(["level_0",'level_1','level_2','level_3','level_4','level_5'], axis = 1)
df.to_csv("new_file.csv", mode='w')
df
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 0         1477             776             845        191       1267
# 1         1912             760             752        392       1094
# 2         1408            1456            1470        500       2033
# 3         1970             681             997        313       1286
# 4         1647             833             866        443       1144
# ..         ...             ...             ...        ...        ...
# 595       1738             693             866        247       1172
# 596       1796             786             944        418       1181
# 597       1628            1129            1402        582       1832
# 598       1999             749             921        359       1256
# 599       1697            1068             715        646       1105
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# ...

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %%
fig, ax = plt.subplots(ncols=2)
sns.boxplot("letter_R_prob", data=prob, ax=ax[0])
sns.histplot(df['letter_R_prob'], ax=ax[1])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='letter_R_prob', ylabel='Count'>

# %%
df.sort_values(by="letter_R_prob",ascending = True)
prob = df[["file_name", "letter_R_prob", "letter_L_prob"]]
prob = prob.sort_values(by="file_name", ascending = True)
prob = prob.set_index(['file_name'])
prob
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1401            0.111130       0.969031
# 1402            0.973859       0.281045
# 1403            0.057326       0.963742
# 1404            0.840128       0.971291
# 1405            0.870817       0.049663
# ...                  ...            ...
# 1996            0.478823       0.892726
# 1997            0.041748       0.972205
# 1998            0.106387       1.029869
# 1999            0.973052       0.196656
# 2000            0.052260       0.967724
#
# [600 rows x 2 columns]

# %%
prob[(prob['letter_R_prob']< 0.2) & (prob['letter_L_prob']<0.2)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1575            0.063318       0.119701
# 1927            0.036292       0.126253

# %%
prob[(prob['letter_L_prob']< 0.5) & (prob['letter_L_prob'] >0.4)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1476            0.756780       0.468159
# 1572            0.955644       0.411431
# 1611            0.955389       0.409130
# 1819            0.969292       0.410175
# 1902            0.909539       0.469484

# %%
prob[(prob['letter_R_prob']< 0.5) & (prob['letter_R_prob'] >0.4)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1500            0.497429       0.933538
# 1503            0.406256       0.701800
# 1798            0.494449       1.004454
# 1996            0.478823       0.892726

# %%
prob[(prob['letter_R_prob']< 0.6) & (prob['letter_R_prob'] >0.5)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1851            0.519742       1.006571
# 1934            0.526429       0.964036

# %%
prob[(prob['letter_R_prob']< 0.7) & (prob['letter_R_prob'] >0.6)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1445            0.611441       0.943235
# 1793            0.652017       1.016316
# 1803            0.606718       0.906948
# 1827            0.661315       0.980722
# 1922            0.671696       0.910350

# %%
prob[(prob['letter_R_prob']< 0.8) & (prob['letter_R_prob'] >0.7)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1453            0.787942       0.967845
# 1476            0.756780       0.468159
# 1544            0.797597       0.078874
# 1552            0.790282       0.877783
# 1752            0.798397       1.020243
# 1757            0.713469       0.917954
# 1797            0.720765       0.586313
# 1855            0.793772       0.833479
# 1879            0.732442       0.903269
# 1921            0.748519       1.020947
# 1942            0.741096       0.113555
# 1957            0.757487       0.117778
# 1972            0.740091       1.025254

# %%
fig, ax = plt.subplots(ncols=2)
sns.boxplot("letter_L_prob", data=prob, ax=ax[0])
sns.histplot(df['letter_L_prob'], ax=ax[1])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='letter_L_prob', ylabel='Count'>

# %%
df[df['file_name'] == 1812]
# Out:
#     file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 42       1812            1165             877        711       1235
#
#     left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 42           1555            845      2042      1170         224         195
#
#     letter_L_x  letter_L_y  right_medial_prob  right_f_prob  left_medial_prob  \
# 42          29         -31           0.987446      0.943662          0.929231
#
#     left_f_prob  letter_R_prob  letter_L_prob
# 42     0.983591        0.99122       1.002785

# %%
df[df['file_name'] == 1802]
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 138       1802             813            1049        444       1339
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 138           1234           1049      1602      1365          -2          23
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 138        1971         497           0.912944      0.925986
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 138          0.945787     0.968324       0.957689       0.975263

# %%
fig, ax = plt.subplots(ncols=2)
sns.boxplot("letter_L_prob", data=df, ax=ax[0])
sns.histplot(df['letter_L_prob'], ax=ax[1])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='letter_L_prob', ylabel='Count'>

# %%
df
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 0         1477             776             845        191       1267
# 1         1912             760             752        392       1094
# 2         1408            1456            1470        500       2033
# 3         1970             681             997        313       1286
# 4         1647             833             866        443       1144
# ..         ...             ...             ...        ...        ...
# 595       1738             693             866        247       1172
# 596       1796             786             944        418       1181
# 597       1628            1129            1402        582       1832
# 598       1999             749             921        359       1256
# 599       1697            1068             715        646       1105
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# ...
