df = df.reset_index()
df['right_medial_prob'] = 0
df['right_f_prob'] = 0
df['left_medial_prob'] = 0
df['left_f_prob'] = 0
df['letter_R_prob'] = 0
df['letter_L_prob'] = 0
df = df.shift(periods=6, axis="columns")
df = df.drop(["level_0",'level_1','level_2','level_3','level_4','level_5'], axis = 1)
df = df.sort_values(by = 'file_name', ascending = True)
df.to_csv("predict_addL.csv", mode='w')
df
# Out:
#      file_name  right_medial_x  right_medial_y  right_f_x  right_f_y  \
# 454       1943             839             865        392       1181
# 335       1944            1003             942        548       1235
# 417       1945             777            1061        415       1311
# 724       1946             990            1104        401       1509
# 676       1947             916            1141        364       1546
# ..         ...             ...             ...        ...        ...
# 330       2769            1285             883        806       1288
# 130       2770             944             892        576       1155
# 725       2771             749             921        359       1256
# 381       2772             833             977        387       1311
# 230       2773            1110            1303        457       1765
#
#      left_medial_x  left_medial_y  left_f_x  left_f_y  letter_R_x  letter_R_y  \
# 454           1207            865      1655      1234        -252        -252
# 335           1490            942      2010      1202          94        1689
# 417           1278           1061      1696      1311          52        1423
# 724           1800           1141      2352      1546        2684         368
# 676           1874           1178      2463      1620          -3        2209
# ..             ...            ...       ...       ...         ...         ...
# 330           1653            920      2132      1325         106         184
# 130           1128            892      1549      1181        1918         339
# 725           1306            893      1724      1228          80        1228
# 381           1418            977      1864      1311        2031         838
# 230           1918           1342      2609      1842         149        1303
#
#      letter_L_x  letter_L_y  right_medial_prob  right_f_prob  \
# 454        1944        1102           0.950554      0.946186
# 335        2740         504           0.985285      0.975298
# 417        2003        1200           0.970455      0.964719
# 724        2684         368           0.980893      0.989219
# 676        2684         184           0.989131      0.957298
# ..          ...         ...                ...           ...
# 330        2389         294           0.965393      0.929857
# 130        1918         339           0.972196      0.995810
# 725        2351         434           0.946024      1.002503
# 381        2031         921           0.978053      0.998790
# 230        3244        1131           0.988435      0.980289
#
#      left_medial_prob  left_f_prob  letter_R_prob  letter_L_prob
# 454          0.982407     0.982963       0.077906       0.953342
# 335          0.963610     0.971712       0.991289       0.268584
# 417          0.953169     0.983693       0.988391       0.908403
# 724          0.957978     0.998329       0.202019       0.991604
# 676          0.963528     0.992729       0.895871       0.987462
# ..                ...          ...            ...            ...
# 330          0.956095     1.004603       0.992114       0.130200
# 130          0.878368     0.952375       0.055441       0.997143
# 725          0.974237     0.960361       1.002244       0.307480
# 381          0.970251     0.974151       0.069277       0.953404
# 230          0.990809     0.926522       0.993832       0.132754
#
# [831 rows x 19 columns]

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %%
fig, ax = plt.subplots(ncols=2)
sns.boxplot("letter_R_prob", data=df, ax=ax[0])
sns.histplot(df['letter_R_prob'], ax=ax[1])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='letter_R_prob', ylabel='Count'>

# %%
fig, ax = plt.subplots(ncols=2)
sns.boxplot("letter_L_prob", data=df, ax=ax[0])
sns.histplot(df['letter_L_prob'], ax=ax[1])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='letter_L_prob', ylabel='Count'>

# %%
df.sort_values(by="letter_R_prob",ascending = True)
prob = df[["file_name", "letter_R_prob", "letter_L_prob"]]
prob = prob.sort_values(by="file_name", ascending = True)
prob = prob.set_index(['file_name'])
prob
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1943            0.077906       0.953342
# 1944            0.991289       0.268584
# 1945            0.988391       0.908403
# 1946            0.202019       0.991604
# 1947            0.895871       0.987462
# ...                  ...            ...
# 2769            0.992114       0.130200
# 2770            0.055441       0.997143
# 2771            1.002244       0.307480
# 2772            0.069277       0.953404
# 2773            0.993832       0.132754
#
# [831 rows x 2 columns]

# %%
prob[(prob['letter_R_prob']< 0.2) & (prob['letter_L_prob']<0.2)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 2212            0.186382       0.071286
# 2401            0.064504       0.188841

# %%
prob[(prob['letter_R_prob']< 0.3) & (prob['letter_L_prob']<0.3)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 2087            0.037278       0.227684
# 2169            0.182223       0.217115
# 2212            0.186382       0.071286
# 2401            0.064504       0.188841
# 2670            0.014149       0.214570

# %%
prob[(prob['letter_R_prob']< 0.4) & (prob['letter_L_prob']<0.4)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1998            0.301204       0.103448
# 2087            0.037278       0.227684
# 2169            0.182223       0.217115
# 2212            0.186382       0.071286
# 2401            0.064504       0.188841
# 2548            0.083007       0.343088
# 2670            0.014149       0.214570

# %%
prob[(prob['letter_R_prob']< 0.46) & (prob['letter_L_prob']<0.46)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1996            0.061585       0.457692
# 1998            0.301204       0.103448
# 2087            0.037278       0.227684
# 2169            0.182223       0.217115
# 2212            0.186382       0.071286
# 2401            0.064504       0.188841
# 2548            0.083007       0.343088
# 2670            0.014149       0.214570

# %%
prob[(prob['letter_L_prob']< 0.5) & (prob['letter_L_prob'] >0.4)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 1996            0.061585       0.457692
# 2028            0.989072       0.414018
# 2038            0.996194       0.411166
# 2193            0.992904       0.447665
# 2211            0.980596       0.431827
# 2246            0.937050       0.476932
# 2342            0.969261       0.474132
# 2366            0.979275       0.421114
# 2446            0.922722       0.454873
# 2466            0.996075       0.444627
# 2518            0.990991       0.444529
# 2603            0.968819       0.425317
# 2723            0.967250       0.416755

# %%
prob[(prob['letter_R_prob']< 0.6) & (prob['letter_R_prob'] >0.5)]
# Out:
#            letter_R_prob  letter_L_prob
# file_name
# 2478            0.547840       1.010820
# 2715            0.568621       0.176081
